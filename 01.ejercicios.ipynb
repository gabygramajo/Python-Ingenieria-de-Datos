# %%
import random

# %%
lista = [random.randint(0,100) for i in range(1,100)]
print(lista)
# Out:
# [11, 78, 80, 33, 45, 79, 57, 1, 82, 44, 64, 59, 96, 97, 90, 56, 99, 11, 2, 78, 88, 5, 23, 48, 65, 2, 0, 48, 86, 24, 64, 59, 89, 27, 77, 33, 51, 62, 89, 62, 69, 7, 33, 45, 38, 21, 15, 85, 55, 36, 26, 19, 68, 51, 52, 63, 42, 84, 67, 3, 24, 56, 80, 87, 27, 8, 88, 67, 37, 85, 48, 48, 37, 42, 0, 78, 40, 78, 87, 21, 10, 39, 84, 11, 14, 10, 23, 6, 83, 80, 16, 87, 70, 90, 55, 18, 2, 91, 91]

# %%
# funcion para sumar numeros pares
def suma_pares(lista):
    return sum(numero for numero in lista if numero % 2 == 0)

print(suma_pares(lista))
# Out:
# 2490

# %%
# funcion para buscar un elemento en una lista
def buscar_elemento(lista, elemento):
    return elemento in lista

print(buscar_elemento(lista, 64))
print(buscar_elemento(lista, 151521))
# Out:
# True
# False

# %%
# Crear una función que reciba una lista de palabras y retorne un diccionario con 
# la cantidad de veces que aparece cada palabra.
def contar_palabras(lista):
    diccionario = {}
    
    for item in lista:
        diccionario[item] = diccionario.get(item, 0) + 1
    
    return diccionario

palabras = ["python", "java", "python", "c++", "python", "java"]
resultado = contar_palabras(palabras)
print(resultado)
# Out:
# {'python': 3, 'java': 2, 'c++': 1}

# %%
# Crear una función que reciba un diccionario donde las llaves sean nombres y los valores sean notas.
# Debe retornar el nombre del alumno con la nota más alta
def mejor_alumno(diccionario):
    alumno_mejor_nota = list(diccionario.keys())[0]
    
    for alumno in diccionario.keys():
        if diccionario.get(alumno) > diccionario.get(alumno_mejor_nota):
            alumno_mejor_nota = alumno
    
    return alumno_mejor_nota

notas = {"Ana": 15, "Luis": 18, "María": 17, "Pedro": 19}


print(mejor_alumno(notas))
# Out:
# Pedro
