# %% [markdown]
# <a href="https://colab.research.google.com/github/institutohumai/cursos-python/blob/master/AnalisisDeDatos/2_Pivot_Table_y_Joins/clase-2.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>
# <div align="center"> Recordá abrir en una nueva pestaña </div>

# %% [markdown]
# # Pivot tables y joins

# %% [markdown]
# ## Tabla de Contenidos
#
#     I. Clase 2: Pivot tables y joins
#         I. Parámetros y extracción de datos
#         II. Pivot table
#             I. Contar casos a partir de un registro
#             II. Crear un panel a partir de un registro
#         III. Concat
#         IV. .str
#             I. .str.replace()
#             II. .str.split()
#         V. .map
#         VI. Merge

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os

from IPython.display import Image
from IPython.core.display import HTML

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Parámetros y extracción de datos

# %%
# Creamos la carpeta "data"
if not os.path.exists('data'): os.makedirs('data')

# input
CASOS_URL = "https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Casos.csv"
DETERMINACIONES_URL = "https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Determinaciones.csv"

CASOS_URL_S3 = "https://storage.googleapis.com/humai-datasets/aws_s3/analisis_de_datos/2_Pivot_Table_y_Joins/covid_casos.zip"
DETERMINACIONES_URL_S3 = "https://storage.googleapis.com/humai-datasets/aws_s3/analisis_de_datos/2_Pivot_Table_y_Joins/covid_determinaciones.csv"

CASOS_PATH = "data/covid_casos.csv"
DETERMINACIONES_PATH = "data/covid_determinaciones.csv"

# output
PANEL_CASOS_PATH = "data/covid19-casos-panel.csv"

# %% [markdown]
# Si los sacamos de internet, podemos usar directamente la URL de cualquier CSV. Siempre es buena práctica guardar una copia por si en algún momento una URL deja de estar disponible.

# %%
converters = {
    "residencia_provincia_id": lambda x: str(x).zfill(2),
    "departamento_provincia_id": lambda x: str(x).zfill(3),
    "codigo_indec_provincia": lambda x: str(x).zfill(2),
    "codigo_indec_departamento": lambda x: str(x).zfill(3),
}

# lee los datos de internet (original)
# casos = pd.read_csv(CASOS_URL, converters=converters)
# determinaciones = pd.read_csv(DETERMINACIONES_URL, converters=converters)

# lee los datos de internet (S3 de humai)
casos = pd.read_csv(CASOS_URL_S3, converters=converters)
determinaciones = pd.read_csv(DETERMINACIONES_URL_S3, converters=converters)

# guarda los datos localmente
casos.to_csv(CASOS_PATH, encoding="utf8", index=False)
determinaciones.to_csv(DETERMINACIONES_PATH, encoding="utf8", index=False)

# lee la copia local
casos = pd.read_csv(CASOS_PATH, converters=converters)
determinaciones = pd.read_csv(DETERMINACIONES_PATH, converters=converters)

# %% [markdown]
# ## Pivot table

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %% [markdown]
# La función de `DataFrame.pivot_table` permite crear una tabla dinámica (de la misma forma que se podría hacer en una planilla de cálculo como Excel) fácilmente, eligiendo qué columnas se quieren mostrar en:
#
# * **índice (index)**: lo que se usa para abrir los datos en filas.
# * **columnas (columns)**: lo que se usa para abrir los datos en columnas.
# * **valores (values)**: las variables que se quieren abrir en filas y columnas.
#
# Y se puede elegir una o más funciones de agregación para aplicar a los valores cuando son agregados.

# %% [markdown]
# ### Contar casos a partir de un registro

# %% [markdown]
# **Casos**
#
# En el dataset de **casos** nos enfrentamos a un **registro**: el dataset es una lista de casos, donde cada fila es un "caso". No tenemos columnas con variables agregadas, tenemos la materia prima sobre la cual se construyen las estadísticas o las agregaciones de cualquier tipo.
#
# Las tablas dinámicas son una buena forma de agregar! En este caso la primera agregación obvia es _contar casos_. Tratemos de **contar la cantidad de casos de Covid por provincia**.

# %%
casos.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'Clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='str')

# %%
# busquemos las columnas que vamos a necesitar usar primero
casos.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0          672064    M  52.0            Años              Argentina
# 1          717629    F  46.0            Años              Argentina
# 2          717926    F  41.0            Años              Argentina
# 3          718029    F  52.0            Años              Argentina
# 4          718055    F  34.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                Buenos Aires               Florencio Varela
# 1                Buenos Aires                      Pergamino
# 2                        CABA                      COMUNA 12
# 3                Buenos Aires                       La Plata
# 4                        CABA                SIN ESPECIFICAR
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires            2020-05-29            NaN  ...
# 1           Buenos Aires            2020-01-29     2020-01-31  ...
# 2                   CABA            2020-01-23     2020-01-31  ...
# 3           Buenos Aires            2020-01-29     2020-01-31  ...
# 4                   CABA            2020-01-16     2020-01-31  ...
#
#    fecha_fallecimiento asistencia_respiratoria_mecanica carga_provincia_id  \
# 0                  NaN                               NO                  6
# 1                  NaN                               NO                  6
# 2                  NaN                               NO                  2
# 3                  NaN                               NO                  6
# 4                  NaN                               NO                  2
#
#   origen_financiamiento                        Clasificacion  \
# 0               Público                      Caso Descartado
# 1               Público                      Caso Descartado
# 2               Público  Caso Invalidado Epidemiologicamente
# 3               Público  Caso Invalidado Epidemiologicamente
# 4               Privado                      Caso Descartado
#
#   clasificacion_resumen residencia_provincia_id  fecha_diagnostico  \
# 0            Descartado                      06         2020-06-01
# 1            Descartado                      06                NaN
# 2            Descartado                      02                NaN
# 3            Descartado                      06                NaN
# 4            Descartado                      02         2020-02-11
#
#   residencia_departamento_id ultima_actualizacion
# 0                        274           2020-06-20
# 1                        623           2020-06-20
# 2                         12           2020-06-20
# 3                        441           2020-06-20
# 4                          0           2020-06-20
#
# [5 rows x 25 columns]

# %%
for col in casos.columns:
    if col.startswith("fecha"):
        print(col)
# Out:
# fecha_inicio_sintomas
# fecha_apertura
# fecha_internacion
# fecha_cui_intensivo
# fecha_fallecimiento
# fecha_diagnostico

# %%
casos.clasificacion_resumen.value_counts()
# Out:
# clasificacion_resumen
# Descartado        189801
# Confirmado         41191
# Sospechoso         20375
# Sin Clasificar         6
# Name: count, dtype: int64

# %%
# Máscara boleana
casos.clasificacion_resumen == "Confirmado"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 251368     True
# 251369    False
# 251370    False
# 251371    False
# 251372    False
# Name: clasificacion_resumen, Length: 251373, dtype: bool

# %%
# aplicando la máscara al df, no quedamos solo con los True, osea lo casos confirmados.
casos[casos.clasificacion_resumen == "Confirmado"].sample(5)
# Out:
#         id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 183324         1045030    F  17.0            Años              Argentina
# 130946          978902    M   6.0            Años              Argentina
# 42198           848027    F  73.0            Años              Argentina
# 217964         1086165    F  29.0            Años              Argentina
# 119816          964292    M  26.0            Años              Argentina
#
#        residencia_provincia_nombre residencia_departamento_nombre  \
# 183324                Buenos Aires                     La Matanza
# 130946                        CABA                       COMUNA 7
# 42198                         CABA                      COMUNA 10
# 217964                Buenos Aires                     La Matanza
# 119816                        CABA                       COMUNA 1
#
#        carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 183324                   CABA            2020-06-07     2020-06-09  ...
# 130946                   CABA                   NaN     2020-05-27  ...
# 42198                    CABA            2020-04-21     2020-04-23  ...
# 217964           Buenos Aires            2020-06-15     2020-06-15  ...
# 119816                   CABA                   NaN     2020-05-24  ...
#
#         fecha_fallecimiento asistencia_respiratoria_mecanica  \
# 183324                  NaN                               NO
# 130946                  NaN                               NO
# 42198                   NaN                               NO
# 217964                  NaN                               NO
# 119816                  NaN                               NO
#
#        carga_provincia_id origen_financiamiento  \
# 183324                  2               Privado
# 130946                  2               Público
# 42198                   2               Privado
# 217964                  6               Público
# 119816                  2               Público
#
#                                             Clasificacion  \
# 183324                 Caso confirmado - Activo Internado
# 130946                          Caso confirmado - Activo
# 42198   Caso confirmado - No Activo por criterio de la...
# 217964                 Caso confirmado - Activo Internado
# 119816                          Caso confirmado - Activo
#
#        clasificacion_resumen residencia_provincia_id  fecha_diagnostico  \
# 183324            Confirmado                      06         2020-06-09
# 130946            Confirmado                      02         2020-05-28
# 42198             Confirmado                      02         2020-04-24
# 217964            Confirmado                      06         2020-06-17
# 119816            Confirmado                      02         2020-05-24
#
#        residencia_departamento_id ultima_actualizacion
# 183324                        427           2020-06-20
# 130946                          7           2020-06-20
# 42198                          10           2020-06-20
# 217964                        427           2020-06-20
# 119816                          1           2020-06-20
#
# [5 rows x 25 columns]

# %% [markdown]
# Creación de la Pivot Table

# %%
# Creamos un Pivot Table con la cantidad de casos confirmados por provincia
casos_provincias = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index="residencia_provincia_nombre",
    values="id_evento_caso",
    aggfunc="count"
)
casos_provincias.sort_values("id_evento_caso", ascending=False)
# Out:
#                              id_evento_caso
# residencia_provincia_nombre
# Buenos Aires                          18535
# CABA                                  18079
# Chaco                                  1530
# Río Negro                               675
# Córdoba                                 552
# Santa Fe                                318
# Neuquén                                 303
# SIN ESPECIFICAR                         271
# Tierra del Fuego                        136
# Entre Ríos                              135
# Mendoza                                 127
# Corrientes                              115
# Chubut                                   86
# La Rioja                                 64
# Tucumán                                  57
# Santa Cruz                               50
# Formosa                                  39
# Misiones                                 39
# Santiago del Estero                      22
# Salta                                    21
# San Luis                                 12
# Jujuy                                    12
# San Juan                                  7
# La Pampa                                  6

# %% [markdown]
# Primer reflejo que siempre tenés que tener: controlar el resultado con algún parámetro conocido (en lo posible). En este caso, tratemos de ver si la suma de casos tiene sentido o no.

# %%
casos_provincias.id_evento_caso.sum()
# Out:
# np.int64(41191)

# %% [markdown]
# En Google se muestra siempre el último dato reportado a la OMS, es un buen control
#
# https://www.google.com/search?q=casos+coronavirus+argentina&oq=casos+coronavirus&aqs=chrome.1.69i57j0l6j69i60.3332j0j7&sourceid=chrome&ie=UTF-8

# %% [markdown]
# **Ejercicio:** crear una tabla contando la cantidad de casos fallecidos y controlarla. Pista: tenés que agregar un filtro más a la tabla anterior, que use la columna "fecha_fallecimiento".

# %%
fallecimiento_provincias = casos[casos.fecha_fallecimiento.notna()].pivot_table(
    index="residencia_provincia_nombre",
    values="id_evento_caso",
    aggfunc="count"
)
fallecimiento_provincias.sort_values("id_evento_caso", ascending=False)
# Out:
#                              id_evento_caso
# residencia_provincia_nombre
# Buenos Aires                           1350
# CABA                                    764
# Chaco                                   160
# Entre Ríos                               82
# Córdoba                                  58
# Mendoza                                  56
# Río Negro                                49
# Santa Fe                                 36
# Misiones                                 21
# La Rioja                                 21
# Neuquén                                  17
# Tucumán                                  16
# Chubut                                   13
# La Pampa                                 12
# Santiago del Estero                       9
# Salta                                     9
# Tierra del Fuego                          7
# Santa Cruz                                7
# Corrientes                                6
# SIN ESPECIFICAR                           5
# San Luis                                  3
# Jujuy                                     1

# %% [markdown]
# ### Crear un panel a partir de un registro

# %% [markdown]
# Una estructura muy común de dataset de **panel** tiene:
#
# * 1 o más variables (generalmente numéricas)
# * 1 dimensión de apertura temporal
# * 1 o más dimensiones de apertura _no temporales_
#
# Convertir registros en paneles, es un paso lógico en el procesamiento de datos primarios hacia la construcción de productos estadísticos o analíticos. Encapsula una parte del esfuerzo que conviene hacer bien de una sola vez, y luego utilizar el panel fácilmente para la mayoría de nuestras necesidades.
#
# En este caso vamos a elegir cuáles son nuestras variables de interés para **construir el panel de casos de Covid**:
#
# * provincia
# * sexo
# * fecha (tiene que haber una dimensión temporal)

# %%
casos_panel = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_diagnostico"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel
# Out:
#      residencia_provincia_id residencia_provincia_nombre sexo  \
# 0                         02                        CABA    F
# 1                         02                        CABA    F
# 2                         02                        CABA    F
# 3                         02                        CABA    F
# 4                         02                        CABA    F
# ...                      ...                         ...  ...
# 1722                      99             SIN ESPECIFICAR    M
# 1723                      99             SIN ESPECIFICAR    M
# 1724                      99             SIN ESPECIFICAR    M
# 1725                      99             SIN ESPECIFICAR   NR
# 1726                      99             SIN ESPECIFICAR   NR
#
#      fecha_diagnostico  id_evento_caso
# 0           2020-03-06               1
# 1           2020-03-13               1
# 2           2020-03-14               3
# 3           2020-03-15               2
# 4           2020-03-16               2
# ...                ...             ...
# 1722        2020-06-18               2
# 1723        2020-06-19               6
# 1724        2020-06-20               1
# 1725        2020-05-30               1
# 1726        2020-06-12               1
#
# [1727 rows x 5 columns]

# %% [markdown]
# Ahora realizar distintos gráficos es muy fácil! Sólo hay que hacer una tabla dinámica sobre nuestro panel eligiendo las variables.

# %%
casos_evolucion_genero = casos_panel.pivot_table(
    columns="sexo",
    index="fecha_diagnostico",
    values="id_evento_caso",
    aggfunc="sum"
)
casos_evolucion_genero
# Out:
# sexo                   F      M    NR
# fecha_diagnostico
# 2020-03-03           NaN    1.0   NaN
# 2020-03-06           2.0    4.0   NaN
# 2020-03-07           NaN    1.0   NaN
# 2020-03-08           NaN    2.0   NaN
# 2020-03-09           5.0    1.0   NaN
# ...                  ...    ...   ...
# 2020-06-16         755.0  833.0  11.0
# 2020-06-17         841.0  899.0   6.0
# 2020-06-18         831.0  840.0   5.0
# 2020-06-19         694.0  670.0   2.0
# 2020-06-20         358.0  363.0   2.0
#
# [108 rows x 3 columns]

# %%
casos_evolucion_genero.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='fecha_diagnostico'>

# %% [markdown]
# **Ejercicio:** graficar la evolución de casos por provincia.

# %%
casos_evolucion_provincia = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    columns="residencia_provincia_nombre",
    index="fecha_diagnostico",
    values="id_evento_caso",
    aggfunc="sum"
)
casos_evolucion_provincia
# Out:
# residencia_provincia_nombre  Buenos Aires         CABA       Chaco  \
# fecha_diagnostico
# 2020-03-03                            NaN     734634.0         NaN
# 2020-03-06                   7.367110e+05    2955785.0         NaN
# 2020-03-07                            NaN     738329.0         NaN
# 2020-03-08                            NaN    1490372.0         NaN
# 2020-03-09                   7.408790e+05     741038.0   1481716.0
# ...                                   ...          ...         ...
# 2020-06-16                   9.341927e+08  701719617.0  27182301.0
# 2020-06-17                   1.069429e+09  696474368.0  60237009.0
# 2020-06-18                   1.041240e+09  630041856.0  45871567.0
# 2020-06-19                   9.380712e+08  463508403.0  16780759.0
# 2020-06-20                   5.687823e+08  152781149.0  12181426.0
#
# residencia_provincia_nombre      Chubut  Corrientes     Córdoba  Entre Ríos  \
# fecha_diagnostico
# 2020-03-03                          NaN         NaN         NaN         NaN
# 2020-03-06                          NaN         NaN    736018.0         NaN
# 2020-03-07                          NaN         NaN         NaN         NaN
# 2020-03-08                          NaN         NaN         NaN         NaN
# 2020-03-09                          NaN         NaN         NaN         NaN
# ...                                 ...         ...         ...         ...
# 2020-06-16                          NaN   1088391.0   3288510.0   7598507.0
# 2020-06-17                   12129784.0   4161690.0   6609835.0   5469474.0
# 2020-06-18                    3300317.0   1107528.0  16668361.0   4398180.0
# 2020-06-19                    2241501.0   3336752.0  20141938.0   1098193.0
# 2020-06-20                          NaN   1123204.0  13149093.0  20990240.0
#
# residencia_provincia_nombre    Formosa      Jujuy  La Pampa  ...   Río Negro  \
# fecha_diagnostico                                            ...
# 2020-03-03                         NaN        NaN       NaN  ...         NaN
# 2020-03-06                         NaN        NaN       NaN  ...         NaN
# 2020-03-07                         NaN        NaN       NaN  ...         NaN
# 2020-03-08                         NaN        NaN       NaN  ...         NaN
# 2020-03-09                         NaN        NaN       NaN  ...    740781.0
# ...                                ...        ...       ...  ...         ...
# 2020-06-16                   1105710.0  2186853.0       NaN  ...  26190104.0
# 2020-06-17                         NaN        NaN       NaN  ...  16399604.0
# 2020-06-18                   1005960.0  1111611.0       NaN  ...  47473078.0
# 2020-06-19                         NaN        NaN       NaN  ...  17801144.0
# 2020-06-20                         NaN        NaN       NaN  ...  14580996.0
#
# residencia_provincia_nombre  SIN ESPECIFICAR      Salta  San Juan  San Luis  \
# fecha_diagnostico
# 2020-03-03                               NaN        NaN       NaN       NaN
# 2020-03-06                               NaN        NaN       NaN       NaN
# 2020-03-07                               NaN        NaN       NaN       NaN
# 2020-03-08                               NaN        NaN       NaN       NaN
# 2020-03-09                               NaN        NaN       NaN  740995.0
# ...                                      ...        ...       ...       ...
# 2020-06-16                        11950400.0        NaN       NaN       NaN
# 2020-06-17                        15334807.0        NaN       NaN       NaN
# 2020-06-18                         9955537.0  1107781.0       NaN  960822.0
# 2020-06-19                        14423123.0        NaN       NaN       NaN
# 2020-06-20                         2146435.0        NaN       NaN       NaN
#
# residencia_provincia_nombre  Santa Cruz    Santa Fe  Santiago del Estero  \
# fecha_diagnostico
# 2020-03-03                          NaN         NaN                  NaN
# 2020-03-06                          NaN         NaN                  NaN
# 2020-03-07                          NaN         NaN                  NaN
# 2020-03-08                          NaN         NaN                  NaN
# 2020-03-09                          NaN         NaN                  NaN
# ...                                 ...         ...                  ...
# 2020-06-16                          NaN   3265031.0                  NaN
# 2020-06-17                          NaN   7711613.0                  NaN
# 2020-06-18                          NaN   8501993.0                  NaN
# 2020-06-19                          NaN  11127954.0                  NaN
# 2020-06-20                          NaN   5611190.0                  NaN
#
# residencia_provincia_nombre  Tierra del Fuego    Tucumán
# fecha_diagnostico
# 2020-03-03                                NaN        NaN
# 2020-03-06                                NaN        NaN
# 2020-03-07                                NaN        NaN
# 2020-03-08                                NaN        NaN
# 2020-03-09                                NaN        NaN
# ...                                       ...        ...
# 2020-06-16                                NaN  1065774.0
# 2020-06-17                                NaN  1066215.0
# 2020-06-18                                NaN        NaN
# 2020-06-19                                NaN        NaN
# 2020-06-20                                NaN        NaN
#
# [108 rows x 24 columns]

# %%
casos_evolucion_provincia.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='fecha_diagnostico'>

# %% [markdown]
# ## Concat

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html

# %% [markdown]
# Pero ahora queremos graficar las curvas de casos confirmados y fallecidos, y nos damos cuenta de que a nuestro panel construido para trabajar le falta una nueva dimensión de apertura de la variable **casos**: el **estado** del caso.
#
# Tenemos que agregar la variable **estado** a nuestro panel, con por lo menos dos estados: **confirmados** y **fallecios**. Para esto vamos a construir paneles **idénticos** para cada una de las variables y concatenarlos.

# %%
casos_panel_confirmados = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_diagnostico"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel_confirmados.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo fecha_diagnostico  \
# 0                      02                        CABA    F        2020-03-06
# 1                      02                        CABA    F        2020-03-13
# 2                      02                        CABA    F        2020-03-14
# 3                      02                        CABA    F        2020-03-15
# 4                      02                        CABA    F        2020-03-16
#
#    id_evento_caso
# 0               1
# 1               1
# 2               3
# 3               2
# 4               2

# %% [markdown]
# Ahora armemos el panel de casos fallecidos con la misma estructura.

# %%
casos_panel_fallecidos = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_fallecimiento"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel_fallecidos.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo  \
# 0                      02                        CABA    F
# 1                      02                        CABA    F
# 2                      02                        CABA    F
# 3                      02                        CABA    F
# 4                      02                        CABA    F
#
#   fecha_fallecimiento  id_evento_caso
# 0          2020-03-25               2
# 1          2020-03-28               1
# 2          2020-04-06               1
# 3          2020-04-07               1
# 4          2020-04-09               2

# %% [markdown]
# Y ahora necesitamos modificar ambos paneles para que tengan la misma estructura, y así poder concatenarlos.
#
# * Agregar una columna para la dimensión "estado"
# * Renombrar las columnas para que sigan teniendo sentido cuando sumemos información

# %%
casos_panel_confirmados["estado"] = "confirmados"
casos_panel_confirmados = casos_panel_confirmados.rename(columns={
    "fecha_diagnostico": "fecha",
    "id_evento_caso": "casos"
})
casos_panel_confirmados.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo       fecha  casos  \
# 0                      02                        CABA    F  2020-03-06      1
# 1                      02                        CABA    F  2020-03-13      1
# 2                      02                        CABA    F  2020-03-14      3
# 3                      02                        CABA    F  2020-03-15      2
# 4                      02                        CABA    F  2020-03-16      2
#
#         estado
# 0  confirmados
# 1  confirmados
# 2  confirmados
# 3  confirmados
# 4  confirmados

# %%
casos_panel_fallecidos["estado"] = "fallecidos"
casos_panel_fallecidos = casos_panel_fallecidos.rename(columns={
    "fecha_fallecimiento": "fecha",
    "id_evento_caso": "casos"
})
casos_panel_fallecidos.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo       fecha  casos  \
# 0                      02                        CABA    F  2020-03-25      2
# 1                      02                        CABA    F  2020-03-28      1
# 2                      02                        CABA    F  2020-04-06      1
# 3                      02                        CABA    F  2020-04-07      1
# 4                      02                        CABA    F  2020-04-09      2
#
#        estado
# 0  fallecidos
# 1  fallecidos
# 2  fallecidos
# 3  fallecidos
# 4  fallecidos

# %% [markdown]
# Y ahora el momento de la verdad! Generemos un solo panel con todos los datos.

# %%
casos_panel2 = pd.concat([casos_panel_confirmados, casos_panel_fallecidos])
casos_panel2
# Out:
#     residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                        02                        CABA    F  2020-03-06
# 1                        02                        CABA    F  2020-03-13
# 2                        02                        CABA    F  2020-03-14
# 3                        02                        CABA    F  2020-03-15
# 4                        02                        CABA    F  2020-03-16
# ..                      ...                         ...  ...         ...
# 455                      90                     Tucumán    F  2020-04-08
# 456                      90                     Tucumán    M  2020-03-29
# 457                      90                     Tucumán    M  2020-04-01
# 458                      99             SIN ESPECIFICAR    M  2020-05-25
# 459                      99             SIN ESPECIFICAR   NR  2020-06-08
#
#      casos       estado
# 0        1  confirmados
# 1        1  confirmados
# 2        3  confirmados
# 3        2  confirmados
# 4        2  confirmados
# ..     ...          ...
# 455      1   fallecidos
# 456      1   fallecidos
# 457      1   fallecidos
# 458      1   fallecidos
# 459      1   fallecidos
#
# [2187 rows x 6 columns]

# %% [markdown]
# Ya podemos graficar fallecidos

# %%
casos_evolucion_genero2 = casos_panel2[
    casos_panel2.estado == "fallecidos"
].pivot_table(
    columns="sexo",
    index="fecha",
    values="casos",
    aggfunc="sum"
)
casos_evolucion_genero2
# Out:
# sexo           F     M   NR
# fecha
# 2020-03-07   NaN   1.0  NaN
# 2020-03-13   NaN   1.0  NaN
# 2020-03-18   NaN   1.0  NaN
# 2020-03-21   1.0   NaN  NaN
# 2020-03-24   NaN   3.0  NaN
# ...          ...   ...  ...
# 2020-06-16   7.0  13.0  NaN
# 2020-06-17  11.0  13.0  NaN
# 2020-06-18   7.0  12.0  1.0
# 2020-06-19   3.0   6.0  NaN
# 2020-06-20   NaN   2.0  NaN
#
# [93 rows x 3 columns]

# %%
casos_evolucion_genero2.plot(figsize=(15,10))
# Out:
# <Axes: xlabel='fecha'>

# %% [markdown]
# **Ejercicio:** crear el panel `casos_panel_descartados` y concatenarlo a los otros dos generando un `casos_panel3`.

# %%
casos.shape
# Out:
# (251373, 25)

# %%
casos.sample(100000).clasificacion_resumen.unique()
# Out:
# <StringArray>
# ['Confirmado', 'Descartado', 'Sospechoso', 'Sin Clasificar']
# Length: 4, dtype: str

# %%
casos.clasificacion_resumen.unique()
# Out:
# <StringArray>
# ['Descartado', 'Sospechoso', 'Confirmado', 'Sin Clasificar']
# Length: 4, dtype: str

# %%
casos_panel_confirmados.columns
# Out:
# Index(['residencia_provincia_id', 'residencia_provincia_nombre', 'sexo',
#        'fecha', 'casos', 'estado'],
#       dtype='str')

# %%
casos[casos.clasificacion_resumen == "Descartado"]["residencia_provincia_nombre"].unique()
# Out:
# <StringArray>
# [       'Buenos Aires',                'CABA',             'Córdoba',
#              'Mendoza',    'Tierra del Fuego',             'Formosa',
#      'SIN ESPECIFICAR',          'Corrientes',            'Santa Fe',
#           'Entre Ríos',            'La Rioja',           'Río Negro',
#             'San Juan',               'Chaco',             'Tucumán',
#             'San Luis',             'Neuquén',            'La Pampa',
#            'Catamarca',              'Chubut',               'Salta',
#  'Santiago del Estero',               'Jujuy',          'Santa Cruz',
#             'Misiones']
# Length: 25, dtype: str

# %%
fechas = list(filter(lambda col : "fecha" in col, casos.columns))
fechas
# Out:
# ['fecha_inicio_sintomas',
#  'fecha_apertura',
#  'fecha_internacion',
#  'fecha_cui_intensivo',
#  'fecha_fallecimiento',
#  'fecha_diagnostico']

# %%
# Panel de descartados
casos_panel_descartados = casos[casos.clasificacion_resumen == "Descartado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "ultima_actualizacion"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel_descartados.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo  \
# 0                      02                        CABA    F
# 1                      02                        CABA    M
# 2                      02                        CABA   NR
# 3                      06                Buenos Aires    F
# 4                      06                Buenos Aires    M
#
#   ultima_actualizacion  id_evento_caso
# 0           2020-06-20           20927
# 1           2020-06-20           18022
# 2           2020-06-20             192
# 3           2020-06-20           42747
# 4           2020-06-20           38747

# %%
casos_panel_descartados["estado"] = "descartados"

casos_panel_descartados = casos_panel_descartados.rename(columns={
    "ultima_actualizacion": "fecha",
    "id_evento_caso": "casos"
})
casos_panel_descartados.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo       fecha  casos  \
# 0                      02                        CABA    F  2020-06-20  20927
# 1                      02                        CABA    M  2020-06-20  18022
# 2                      02                        CABA   NR  2020-06-20    192
# 3                      06                Buenos Aires    F  2020-06-20  42747
# 4                      06                Buenos Aires    M  2020-06-20  38747
#
#         estado
# 0  descartados
# 1  descartados
# 2  descartados
# 3  descartados
# 4  descartados

# %%
casos_panel3 = pd.concat([casos_panel2, casos_panel_descartados])
casos_panel3.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo       fecha  casos  \
# 0                      02                        CABA    F  2020-03-06      1
# 1                      02                        CABA    F  2020-03-13      1
# 2                      02                        CABA    F  2020-03-14      3
# 3                      02                        CABA    F  2020-03-15      2
# 4                      02                        CABA    F  2020-03-16      2
#
#         estado
# 0  confirmados
# 1  confirmados
# 2  confirmados
# 3  confirmados
# 4  confirmados

# %% [markdown]
# ## .str

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.html

# %% [markdown]
# Todas las columnas (Series) de un data frame tienen diferentes métodos asociados que se pueden utilzar para hacer transformaciones rápidamente.
#
# Hay un grupo de ellos accesible a través del atributo `str` (`Series.str`) que implementa las funciones usuales de Python sobre strings, para una columna de valores de texto.

# %% [markdown]
# ### .str.replace()

# %% [markdown]
# Si queremos graficar la evolución de casos por sexo, pero queremos una leyenda con la palabra completa, tal vez necesitemos reemplazar los valores usados en el dataset por otros.

# %%
casos_panel2.head()
# Out:
#   residencia_provincia_id residencia_provincia_nombre sexo       fecha  casos  \
# 0                      02                        CABA    F  2020-03-06      1
# 1                      02                        CABA    F  2020-03-13      1
# 2                      02                        CABA    F  2020-03-14      3
# 3                      02                        CABA    F  2020-03-15      2
# 4                      02                        CABA    F  2020-03-16      2
#
#         estado
# 0  confirmados
# 1  confirmados
# 2  confirmados
# 3  confirmados
# 4  confirmados

# %%
casos_panel2["sexo"] = casos_panel2.sexo.str.replace(
    "F", "Femenino"
).replace(
    "M", "Masculino"
).replace(
    "NR", "No responde"
)

# %%
casos_panel2.sexo.value_counts()
# Out:
# sexo
# Masculino      1124
# Femenino        977
# No responde      86
# Name: count, dtype: int64

# %% [markdown]
# **Ejercicio:** modificar la columna `residencia_provincia_nombre` reemplazando "CABA" por "Ciudad Autónoma de Buenos Aires".

# %%
casos_panel2.columns
# Out:
# Index(['residencia_provincia_id', 'residencia_provincia_nombre', 'sexo',
#        'fecha', 'casos', 'estado'],
#       dtype='str')

# %%
casos_panel2["residencia_provincia_nombre"] = casos_panel2.residencia_provincia_nombre.str.replace("CABA", "Ciudad Autónoma de Buenos Aires")

# %%
casos_panel2.residencia_provincia_nombre.value_counts().head(3)
# Out:
# residencia_provincia_nombre
# Buenos Aires                       395
# Ciudad Autónoma de Buenos Aires    387
# Chaco                              250
# Name: count, dtype: int64

# %% [markdown]
# ###  .str.split()

# %% [markdown]
# Si queremos agrupar por mes, tal vez necesitamos partir la fecha en tres partes.

# %%
split_fecha = casos_panel2.fecha.str.split("-", expand=True)

# %%
split_fecha
# Out:
#         0   1   2
# 0    2020  03  06
# 1    2020  03  13
# 2    2020  03  14
# 3    2020  03  15
# 4    2020  03  16
# ..    ...  ..  ..
# 455  2020  04  08
# 456  2020  03  29
# 457  2020  04  01
# 458  2020  05  25
# 459  2020  06  08
#
# [2187 rows x 3 columns]

# %%
casos_panel2['anio'] = split_fecha[0]
casos_panel2['mes'] = split_fecha[1]
casos_panel2['dia'] = split_fecha[2]

# %%
casos_panel2
# Out:
#     residencia_provincia_id      residencia_provincia_nombre         sexo  \
# 0                        02  Ciudad Autónoma de Buenos Aires     Femenino
# 1                        02  Ciudad Autónoma de Buenos Aires     Femenino
# 2                        02  Ciudad Autónoma de Buenos Aires     Femenino
# 3                        02  Ciudad Autónoma de Buenos Aires     Femenino
# 4                        02  Ciudad Autónoma de Buenos Aires     Femenino
# ..                      ...                              ...          ...
# 455                      90                          Tucumán     Femenino
# 456                      90                          Tucumán    Masculino
# 457                      90                          Tucumán    Masculino
# 458                      99                  SIN ESPECIFICAR    Masculino
# 459                      99                  SIN ESPECIFICAR  No responde
#
#           fecha  casos       estado  anio mes dia
# 0    2020-03-06      1  confirmados  2020  03  06
# 1    2020-03-13      1  confirmados  2020  03  13
# 2    2020-03-14      3  confirmados  2020  03  14
# 3    2020-03-15      2  confirmados  2020  03  15
# 4    2020-03-16      2  confirmados  2020  03  16
# ..          ...    ...          ...   ...  ..  ..
# 455  2020-04-08      1   fallecidos  2020  04  08
# 456  2020-03-29      1   fallecidos  2020  03  29
# 457  2020-04-01      1   fallecidos  2020  04  01
# 458  2020-05-25      1   fallecidos  2020  05  25
# 459  2020-06-08      1   fallecidos  2020  06  08
#
# [2187 rows x 9 columns]

# %% [markdown]
# **Ejercicio:** separar la fecha en "anio", "mes" y "dia" en el `casos_panel3` que crearon antes.

# %%
casos_panel3.columns
# Out:
# Index(['residencia_provincia_id', 'residencia_provincia_nombre', 'sexo',
#        'fecha', 'casos', 'estado'],
#       dtype='str')

# %%
split_fecha3 = casos_panel3.fecha.str.split("-", expand=True)
casos_panel3["anio"] = split_fecha3[0]
casos_panel3["mes"] = split_fecha3[1]
casos_panel3["dia"] = split_fecha3[2]
casos_panel3
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                       02                        CABA    F  2020-03-06
# 1                       02                        CABA    F  2020-03-13
# 2                       02                        CABA    F  2020-03-14
# 3                       02                        CABA    F  2020-03-15
# 4                       02                        CABA    F  2020-03-16
# ..                     ...                         ...  ...         ...
# 64                      94            Tierra del Fuego    M  2020-06-20
# 65                      94            Tierra del Fuego   NR  2020-06-20
# 66                      99             SIN ESPECIFICAR    F  2020-06-20
# 67                      99             SIN ESPECIFICAR    M  2020-06-20
# 68                      99             SIN ESPECIFICAR   NR  2020-06-20
#
#     casos       estado  anio mes dia
# 0       1  confirmados  2020  03  06
# 1       1  confirmados  2020  03  13
# 2       3  confirmados  2020  03  14
# 3       2  confirmados  2020  03  15
# 4       2  confirmados  2020  03  16
# ..    ...          ...   ...  ..  ..
# 64    768  descartados  2020  06  20
# 65      4  descartados  2020  06  20
# 66    366  descartados  2020  06  20
# 67    234  descartados  2020  06  20
# 68      9  descartados  2020  06  20
#
# [2256 rows x 9 columns]

# %% [markdown]
# ## .map

# %% [markdown]
# Tal vez notaron lo impráctico que puede resultar el método `.str.replace()` cuando la lista de reemplazos sea larga. Para este caso existe el método `.map()`, al que se le puede pasar un diccionario con los reemplazos.

# %%
casos_panel2["sexo"] = casos_panel2.sexo.map({
    "Masculino": "Masc",
    "Femenino": "Fem",
    "No responde": "Sin especificar"
})

# %%
casos_panel2.sexo.value_counts()
# Out:
# sexo
# Masc               1124
# Fem                 977
# Sin especificar      86
# Name: count, dtype: int64

# %% [markdown]
# **Ejercicio:** modificar las categorías de la columna "estado" por "positivos" (en lugar de "confirmados"), "decesos" (en lugar de "fallecidos") y "negativos" (en lugar de "descartados").

# %%
casos_panel3.columns
# Out:
# Index(['residencia_provincia_id', 'residencia_provincia_nombre', 'sexo',
#        'fecha', 'casos', 'estado', 'anio', 'mes', 'dia'],
#       dtype='str')

# %%
casos_panel3["estado"] = casos_panel3.estado.map({
    "confirmados": "positivos",
    "fallecidos": "decesos",
    "descartados": "negativos",
})
casos_panel3.estado.value_counts()
# Out:
# estado
# positivos    1727
# decesos       460
# negativos      69
# Name: count, dtype: int64

# %% [markdown]
# ## Merge

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %% [markdown]
# "Mergear", "joinear" o cruzar dos datasets, implica elegir una o más columnas que estos tengan en común y utilizarlas para cruzar ambas tablas en base a la coincidencia de valores entre ambas. Existen varios tipos de _joins_ según cuál es el resultado que nos interesa obtener al final con la cruza:
#
# * **left join**: preserva el 100% de las filas que tiene la tabla _de la izquierda_ del merge, y agrega las columnas del dataset _de la derecha_ con los valores (cuando hay una coincidencia) o las llena con valores nulos (cuando no hay coincidencia). Si el dataset de la derecha tiene valores para filas que no están presentes en el dataset de la izquierda, simplemente no se utilizan. El dataset resultado tiene la misma cantidad de filas que el dataset de la izquierda.
# * **right join**: es igual que el anterior, pero se preservan las filas del dataset de la derecha en lugar de las del de la izquierda.
# * **inner join**: sólo se mantienen aquellas filas que coinciden _en ambos datasets_. Si alguna fila no tiene coincidencia en uno de los dos, se descarta. El dataset final tiene igual cantidad o menos filas que el dataset más grande.
# * **outer join**: se preservan todas las filas. Si hay coincidencia, se cruzan, y si no hay coincidencia se apilan llenando con valores nulos.
#
# El tipo de join más común que van a utilizar la mayoría de las veces es el **left join**, cuyo caso de uso es "tengo una tabla, y quiero enriquecerla con nuevas columnas".

# %%
Image(url= "https://storage.googleapis.com/humai-datasets/imagenes/analisis_de_datos/2_Pivot_Table_y_Joins/joins.png")
# Out:
# <img src="https://storage.googleapis.com/humai-datasets/imagenes/analisis_de_datos/2_Pivot_Table_y_Joins/joins.png"/>

# %% [markdown]
# Ahora, queremos calcular y graficar un indicador utilizado en algunos análisis que es la cantidad de testeos sobre la cantidad de casos confirmados.
#
# Este indicador nos dice cuántos tests están siendo necesarios para identificar cada caso positivo de Covid. Para esto vamos a necesitar cruzar los datos de **determinaciones** con los de **casos**.
#
# Hasta ahora nuestro panel tenía una sola variable! Pero ya es hora de que le agreguemos otra: `tests`.

# %%
casos_panel2
# Out:
#     residencia_provincia_id      residencia_provincia_nombre             sexo  \
# 0                        02  Ciudad Autónoma de Buenos Aires              Fem
# 1                        02  Ciudad Autónoma de Buenos Aires              Fem
# 2                        02  Ciudad Autónoma de Buenos Aires              Fem
# 3                        02  Ciudad Autónoma de Buenos Aires              Fem
# 4                        02  Ciudad Autónoma de Buenos Aires              Fem
# ..                      ...                              ...              ...
# 455                      90                          Tucumán              Fem
# 456                      90                          Tucumán             Masc
# 457                      90                          Tucumán             Masc
# 458                      99                  SIN ESPECIFICAR             Masc
# 459                      99                  SIN ESPECIFICAR  Sin especificar
#
#           fecha  casos       estado  anio mes dia
# 0    2020-03-06      1  confirmados  2020  03  06
# 1    2020-03-13      1  confirmados  2020  03  13
# 2    2020-03-14      3  confirmados  2020  03  14
# 3    2020-03-15      2  confirmados  2020  03  15
# 4    2020-03-16      2  confirmados  2020  03  16
# ..          ...    ...          ...   ...  ..  ..
# 455  2020-04-08      1   fallecidos  2020  04  08
# 456  2020-03-29      1   fallecidos  2020  03  29
# 457  2020-04-01      1   fallecidos  2020  04  01
# 458  2020-05-25      1   fallecidos  2020  05  25
# 459  2020-06-08      1   fallecidos  2020  06  08
#
# [2187 rows x 9 columns]

# %% [markdown]
# ¿Cómo hacemos esto? Para cruzar (o "joinear") un dataset con otro, necesitamos definir un conjunto de columnas común por el cual hacerlo, esto a veces se llama **clave primaria** (o "primary key").
#
# La clave primaria de una tabla es el conjunto de columnas necesarias para identificar a una sola fila de la tabla. Si miramos nuestro último panel, vemos que necesitamos las columnas **provincia**, **sexo**, **fecha** y **estado**.

# %%
determinaciones
# Out:
#            fecha         provincia codigo_indec_provincia  departamento  \
# 0     2020-02-11              CABA                     02      COMUNA 4
# 1     2020-02-20              CABA                     02      COMUNA 4
# 2     2020-02-20      Buenos Aires                     06  Bahía Blanca
# 3     2020-02-27              CABA                     02      COMUNA 4
# 4     2020-02-28              CABA                     02      COMUNA 4
# ...          ...               ...                    ...           ...
# 6732  2020-06-20          Santa Fe                     82       Rosario
# 6733  2020-06-20          Santa Fe                     82       Rosario
# 6734  2020-06-20  Tierra del Fuego                     94       Ushuaia
# 6735  2020-06-20           Tucumán                     90     Cruz Alta
# 6736  2020-06-20           Tucumán                     90       Capital
#
#      codigo_indec_departamento              localidad  codigo_indec_localidad  \
# 0                          004       PARQUE PATRICIOS                      10
# 1                          004       PARQUE PATRICIOS                      10
# 2                          056           BAHIA BLANCA                      10
# 3                          004       PARQUE PATRICIOS                      10
# 4                          004       PARQUE PATRICIOS                      10
# ...                        ...                    ...                     ...
# 6732                       084                ROSARIO                     270
# 6733                       084                ROSARIO                     270
# 6734                       014                USHUAIA                      20
# 6735                       014     BANDA DEL RIO SALI                      20
# 6736                       084  SAN MIGUEL DE TUCUMAN                      10
#
#      origen_de_financiamiento        tipo ultima_actualizacion  total  \
# 0                     Público    Nacional           2020-06-20      2
# 1                     Público    Nacional           2020-06-20      1
# 2                     Privado     Privado           2020-06-20      1
# 3                     Público    Nacional           2020-06-20      4
# 4                     Público    Nacional           2020-06-20     10
# ...                       ...         ...                  ...    ...
# 6732                  Privado     Privado           2020-06-20      1
# 6733                  Público   Municipal           2020-06-20     19
# 6734                  Público  Provincial           2020-06-20      3
# 6735                  Público  Provincial           2020-06-20      2
# 6736                  Público  Provincial           2020-06-20      4
#
#       positivos
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 6732        1.0
# 6733        3.0
# 6734        NaN
# 6735        NaN
# 6736        NaN
#
# [6737 rows x 12 columns]

# %% [markdown]
# Sin embargo el panel de "determinaciones" sólo comparte las columnas **fecha** y **provincia**, así que necesitamos generar dos paneles con esa clave primaria para poder cruzarlos.

# %%
casos_confirmados_provincias = casos_panel2[
    casos_panel2.estado == "confirmados"
].pivot_table(
    index=["residencia_provincia_id", "fecha"],
    values="casos",
    aggfunc="sum"
).reset_index()

casos_confirmados_provincias
# Out:
#      residencia_provincia_id       fecha  casos
# 0                         02  2020-03-03      1
# 1                         02  2020-03-06      4
# 2                         02  2020-03-07      1
# 3                         02  2020-03-08      2
# 4                         02  2020-03-09      1
# ...                      ...         ...    ...
# 1006                      99  2020-06-16     11
# 1007                      99  2020-06-17     14
# 1008                      99  2020-06-18      9
# 1009                      99  2020-06-19     13
# 1010                      99  2020-06-20      2
#
# [1011 rows x 3 columns]

# %% [markdown]
# Siempre recuerden controlar el resultado!

# %%
casos_confirmados_provincias.casos.sum()
# Out:
# np.int64(41191)

# %% [markdown]
# Ahora hacemos un panel de determinaciones con la misma estructura.

# %%
determinaciones_panel = determinaciones.pivot_table(
    index=["codigo_indec_provincia", "fecha"],
    values="total",
    aggfunc="sum"
).reset_index()

determinaciones_panel
# Out:
#      codigo_indec_provincia       fecha  total
# 0                        02  2020-02-11      2
# 1                        02  2020-02-20      1
# 2                        02  2020-02-27      4
# 3                        02  2020-02-28     10
# 4                        02  2020-03-02      5
# ...                     ...         ...    ...
# 1885                     94  2020-06-20      3
# 1886                     99  2020-05-22      1
# 1887                     99  2020-06-03      1
# 1888                     99  2020-06-12      1
# 1889                     99  2020-06-14      2
#
# [1890 rows x 3 columns]

# %%
determinaciones_panel.total.sum()
# Out:
# np.int64(280326)

# %% [markdown]
# Llegó el momento del join! Recordemos que el objetivo es terminar con un solo panel, donde haya ahora dos variables: **casos** y **tests** ; con apertura por las dos dimensiones que comparten los datasets: **provincia** y **fecha**.
#
# Para esto vamos a usar la función `DataFrame.merge()`.

# %%
casos_tests = casos_confirmados_provincias.merge(
    determinaciones_panel,
    left_on=["residencia_provincia_id", "fecha"],
    right_on=["codigo_indec_provincia", "fecha"]
)

casos_tests
# Out:
#     residencia_provincia_id       fecha  casos codigo_indec_provincia  total
# 0                        02  2020-03-03      1                     02      8
# 1                        02  2020-03-06      4                     02     11
# 2                        02  2020-03-07      1                     02      9
# 3                        02  2020-03-08      2                     02     28
# 4                        02  2020-03-09      1                     02     13
# ..                      ...         ...    ...                    ...    ...
# 879                      94  2020-05-26      1                     94     23
# 880                      99  2020-05-22      5                     99      1
# 881                      99  2020-06-03      4                     99      1
# 882                      99  2020-06-12     10                     99      1
# 883                      99  2020-06-14      8                     99      2
#
# [884 rows x 5 columns]

# %% [markdown]
# Bien! Noten que si la columna coincide en nombre, quedará una sola columna, pero si los nombres son diferentes tendremos una columna duplicada (que no queremos). Además deberíamos clarificar el nombre de la segunda variable.

# %%
casos_tests = casos_tests.drop(
    columns=["codigo_indec_provincia"]
)
casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  total
# 0                        02  2020-03-03      1      8
# 1                        02  2020-03-06      4     11
# 2                        02  2020-03-07      1      9
# 3                        02  2020-03-08      2     28
# 4                        02  2020-03-09      1     13
# ..                      ...         ...    ...    ...
# 879                      94  2020-05-26      1     23
# 880                      99  2020-05-22      5      1
# 881                      99  2020-06-03      4      1
# 882                      99  2020-06-12     10      1
# 883                      99  2020-06-14      8      2
#
# [884 rows x 4 columns]

# %%
casos_tests = casos_tests.rename(
    columns={"total": "tests"}
)
casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  tests
# 0                        02  2020-03-03      1      8
# 1                        02  2020-03-06      4     11
# 2                        02  2020-03-07      1      9
# 3                        02  2020-03-08      2     28
# 4                        02  2020-03-09      1     13
# ..                      ...         ...    ...    ...
# 879                      94  2020-05-26      1     23
# 880                      99  2020-05-22      5      1
# 881                      99  2020-06-03      4      1
# 882                      99  2020-06-12     10      1
# 883                      99  2020-06-14      8      2
#
# [884 rows x 4 columns]

# %% [markdown]
# ¿Por qué no usamos concat en lugar de merge, y agregamos una columna que se llame `variable` y tenga los valores "casos" y "tests"?
#
# Esto también hubiera sido una estructura de panel posible, con sus ventajas y desventajas. Si tuviéramos una _gran cantidad_ de variables tal vez es mejor elegir esa estructura de dataset **más vertical**, pero si tenemos pocas, tal vez es mejor que cada variable sea una columna.
#
# ¿No son casos confirmados y casos fallecidos variables distintas también? Sí, podría pensarse así. Pero en este caso sí es más claro que se puede modelar como una variable **casos** con una dimensión de apertura que es el **estado** del caso.

# %% [markdown]
# Ahora queremos calcular una nueva variable: tests x caso confirmado.

# %%
casos_tests["tests_por_confirmado"] = casos_tests.tests / casos_tests.casos

casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  tests  tests_por_confirmado
# 0                        02  2020-03-03      1      8                  8.00
# 1                        02  2020-03-06      4     11                  2.75
# 2                        02  2020-03-07      1      9                  9.00
# 3                        02  2020-03-08      2     28                 14.00
# 4                        02  2020-03-09      1     13                 13.00
# ..                      ...         ...    ...    ...                   ...
# 879                      94  2020-05-26      1     23                 23.00
# 880                      99  2020-05-22      5      1                  0.20
# 881                      99  2020-06-03      4      1                  0.25
# 882                      99  2020-06-12     10      1                  0.10
# 883                      99  2020-06-14      8      2                  0.25
#
# [884 rows x 5 columns]

# %%
casos_tests[
    casos_tests.residencia_provincia_id == "02"
].set_index(
    "fecha"
).tests_por_confirmado.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='fecha'>

# %% [markdown]
# Esta variable puede tener variadas interpretaciones. ¿Qué significa si baja? ¿Se están haciendo los testeos focalizados en zonas con brotes? ¿Se necesitan hacer más tests para estar seguro de que se detecta la cantidad de casos necesarios para localizar los brotes?
#
# Hay muchas interpretaciones posibles, y probablemente requieran de una interpretación más sofisticada. Se lo dejamos a los expertos!

# %% [markdown]
# **Ejercicio:** repetir el gráfico para otras provincias y analizar si se comportan de forma similar.

# %%
casos_tests.residencia_provincia_id.value_counts().head(3)
# Out:
# residencia_provincia_id
# 02    108
# 06     96
# 22     87
# Name: count, dtype: int64

# %%
casos_tests[
    casos_tests.residencia_provincia_id == "06"
].set_index(
    "fecha"
).tests_por_confirmado.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='fecha'>

# %%
casos_tests[
    casos_tests.residencia_provincia_id == "22"
].set_index(
    "fecha"
).tests_por_confirmado.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='fecha'>
